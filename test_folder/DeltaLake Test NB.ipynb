# %%
spark

# %%
spark.conf.get("spark.sql.catalogImplementation")

# %%
# %sql
show databases

# %%
df_read_csv = spark.read.csv("/Volumes/hashdatabricksworksapce/hashs-schema/hashs-schema-volume-input/orders_data.csv", header=True)

# %%
SHOW VOLUMES

# %%
dbutils.fs.ls("/Volumes/hashdatabricksworksapce/hashs-schema/hashs-schema-volume-output")

# %%
df_read_csv.write.mode("overwrite").option("path", "/Volumes/hashdatabricksworksapce/hashs-schema/hashs-schema-volume-output").saveAsTable("orders_data_parquet")
